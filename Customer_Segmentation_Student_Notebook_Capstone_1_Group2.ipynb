# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to "RFM Customer Segmentation & Cohort Analysis Project". This is the first project of the Capstone Project Series, which consists of 3 different project that contain different scenarios.
#
# This is a project which you will learn what is RFM? And how to apply RFM Analysis and Customer Segmentation using K-Means Clustering. Also you will improve your Data Cleaning, Data Visualization and Exploratory Data Analysis capabilities. On the other hand you will create Cohort and Conduct Cohort Analysis.
#
# Before diving into the project, please take a look at the determines and project structure.
#
# - **NOTE:** This Project assumes that you already know the basics of coding in Python and are familiar with the theory behind K-Means Clustering.

# %% [markdown]
# # #Determines
#
# Using the [Online Retail dataset](https://archive.ics.uci.edu/ml/datasets/Online+Retail) from the UCI Machine Learning Repository for exploratory data analysis, ***Customer Segmentation***, ***RFM Analysis***, ***K-Means Clustering*** and ***Cohort Analysis***.
#
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# Feature Information:
#
# **InvoiceNo**: Invoice number. *Nominal*, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# <br>
# **StockCode**: Product (item) code. *Nominal*, a 5-digit integral number uniquely assigned to each distinct product.
# <br>
# **Description**: Product (item) name. *Nominal*.
# <br>
# **Quantity**: The quantities of each product (item) per transaction. *Numeric*.
# <br>
# **InvoiceDate**: Invoice Date and time. *Numeric*, the day and time when each transaction was generated.
# <br>
# **UnitPrice**: Unit price. *Numeric*, Product price per unit in sterling.
# <br>
# **CustomerID**: Customer number. *Nominal*, a 5-digit integral number uniquely assigned to each customer.
# <br>
# **Country**: Country name. *Nominal*, the name of the country where each customer resides.
#
#
# ---
#
#
# First of all, to observe the structure of the data and missing values, you can use exploratory data analysis and data visualization techniques.
#
# You must do descriptive analysis. Because you must understand the relationship of the features to each other and clear the noise and missing values in the data. After that, the data set will be ready for RFM analysis.
#
# Before starting the RFM Analysis, you will be asked to do some analysis regarding the distribution of *Orders*, *Customers* and *Countries*. These analyzes will help the company develop its sales policies and contribute to the correct use of resources.
#
# You will notice that the UK not only has the most sales revenue, but also the most customers. So you will continue to analyze only UK transactions in the next RFM Analysis, Customer Segmentation and K-Means Clustering topics.
#
# Next, you will begin RFM Analysis, a customer segmentation technique based on customers' past purchasing behavior.
#
# By using RFM Analysis, you can enable companies to develop different approaches to different customer segments so that they can get to know their customers better, observe trends better, and increase customer retention and sales revenues.
#
# You will calculate the Recency, Frequency and Monetary values of the customers in the RFM Analysis you will make using the data consisting of UK transactions. Ultimately, you have to create an RFM table containing these values.
#
# In the Customer Segmentation section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".
#
# We will segment the customers ourselves based on their recency, frequency, and monetary values. But can an **unsupervised learning** model do this better for us? You will use the K-Means algorithm to find the answer to this question. Then you will compare the classification made by the algorithm with the classification you have made yourself.
#
# Before applying K-Means Clustering, you should do data pre-processing. In this context, it will be useful to examine feature correlations and distributions. In addition, the data you apply for K-Means should be normalized.
#
# On the other hand, you should inform the K-means algorithm about the number of clusters it will predict. You will also try the *** Elbow method *** and *** Silhouette Analysis *** to find the optimum number of clusters.
#
# After the above operations, you will have made cluster estimation with K-Means. You should visualize the cluster distribution by using a scatter plot. You can observe the properties of the resulting clusters with the help of the boxplot. Thus you will be able to tag clusters and interpret results.
#
# Finally, you will do Cohort Analysis with the data you used at the beginning, regardless of the analysis you have done before. Cohort analysis is a subset of behavioral analytics that takes the user data and breaks them into related groups for analysis. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.

# %% [markdown]
# # #Project Structures
#
# - Data Cleaning & Exploratory Data Analysis
# - RFM Analysis
# - Customer Segmentation
# - Applying K-Means Clustering
# - Create Cohort and Conduct Cohort Analysis

# %% [markdown]
# # #Tasks
#
# #### 1. Data Cleaning & Exploratory Data Analysis
#
# - Import Modules, Load Data & Data Review
# - Follow the Steps Below
#
#     *i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.*
#
#     *ii. What does the letter "C" in the invoiceno column mean?*
#
#     *iii. Handling Missing Values*
#
#     *iv. Clean the Data from the Noise and Missing Values*
#
#     *v. Explore the Orders*
#
#     *vi. Explore Customers by Country*
#
#     *vii. Explore the UK Market*
#
# #### 2. RFM Analysis
#
# - Follow the steps below
#
#    *i. Import Libraries*
#
#    *ii. Review "df_uk" DataFrame (the df_uk what you create at the end of the Task 1)*
#
#    *iii. Calculate Recency*
#
#    *iv. Calculate Frequency*
#
#    *v. Calculate Monetary Values*
#
#    *vi. Create RFM Table*
#
# #### 3. Customer Segmentation with RFM Scores
# - Calculate RFM Scoring
#
#     *i. Creating the RFM Segmentation Table*
#
# - Plot RFM Segments
#
# #### 4. Applying K-Means Clustering
# - Data Pre-Processing and Exploring
#
#     *i. Define and Plot Feature Correlations*
#
#     *ii. Visualize Feature Distributions*
#
#     *iii. Data Normalization*
#
# - K-Means Implementation
#
#     *i. Define Optimal Cluster Number (K) by using "Elbow Method" and "Silhouette Analysis"*
#
#     *ii. Visualize the Clusters*
#
#     *iii. Assign the label*
#
#     *iv. Conclusion*
#
# #### 5. Create Cohort and Conduct Cohort Analysis
# - Future Engineering
#
#     *i. Extract the Month of the Purchase*
#
#     *ii. Calculating time offset in Months i.e. Cohort Index*
#
# - Create 1st Cohort: User Number & Retention Rate
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 1 using seaborn and matplotlib*
#
# - Create 2nd Cohort: Average Quantity Sold
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 2 using seaborn and matplotlib*
#
# - Create 3rd Cohort: Average Sales
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 3 using seaborn and matplotlib*
#
# - **Note: There may be sub-tasks associated with each task, you will see them in order during the course of the work.**

# %% [markdown]
# # 1. Data Cleaning & Exploratory Data Analysis

# %% [markdown]
# ## Import Modules, Load Data & Data Review

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (10,6)
pd.set_option('display.max_rows', 500)

# Read the Excel file
excel_path = "Online Retail.xlsx"


# Save it as a CSV file
csv_path = "OnlineRetailData.csv"
df = pd.read_excel(excel_path)
df.to_csv(csv_path, index=False)


# Turn the file to pickle format and read it
# data.to_pickle('Online Retail.pkl')
# df = pd.read_pickle('Online Retail.pkl')

# %%
# pip install openpyxl

# %%
df.head(20)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10    536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11    536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# 12    536367     22749    FELTCRAFT PRINCESS CHARLOTTE DOLL         8
# 13    536367     22310              IVORY KNITTED MUG COSY          6
# 14    536367     84969   BOX OF 6 ASSORTED COLOUR TEASPOONS         6
# 15    536367     22623        BOX OF VINTAGE JIGSAW BLOCKS          3
# 16    536367     22622       BOX OF VINTAGE ALPHABET BLOCKS         2
# 17    536367     21754             HOME BUILDING BLOCK WORD         3
# 18    536367     21755             LOVE BUILDING BLOCK WORD         3
# 19    536367     21777          RECIPE BOX WITH METAL HEART         4
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 5  2010-12-01 08:26:00       7.65     17850.0  United Kingdom
# 6  2010-12-01 08:26:00       4.25     17850.0  United Kingdom
# 7  2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 8  2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 9  2010-12-01 08:34:00       1.69     13047.0  United Kingdom
# 10 2010-12-01 08:34:00       2.10     13047.0  United Kingdom
# 11 2010-12-01 08:34:00       2.10     13047.0  United Kingdom
# 12 2010-12-01 08:34:00       3.75     13047.0  United Kingdom
# 13 2010-12-01 08:34:00       1.65     13047.0  United Kingdom
# 14 2010-12-01 08:34:00       4.25     13047.0  United Kingdom
# 15 2010-12-01 08:34:00       4.95     13047.0  United Kingdom
# 16 2010-12-01 08:34:00       9.95     13047.0  United Kingdom
# 17 2010-12-01 08:34:00       5.95     13047.0  United Kingdom
# 18 2010-12-01 08:34:00       5.95     13047.0  United Kingdom
# 19 2010-12-01 08:34:00       7.95     13047.0  United Kingdom

# %%
df.tail(20)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
# 541894    581587     22631             CIRCUS PARADE LUNCH BOX         12
# 541895    581587     22556       PLASTERS IN TIN CIRCUS PARADE         12
# 541896    581587     22555            PLASTERS IN TIN STRONGMAN        12
# 541897    581587     22728            ALARM CLOCK BAKELIKE PINK         4
# 541898    581587     22727            ALARM CLOCK BAKELIKE RED          4
# 541899    581587     22726           ALARM CLOCK BAKELIKE GREEN         4
# 541900    581587     22730           ALARM CLOCK BAKELIKE IVORY         4
# 541901    581587     22367      CHILDRENS APRON SPACEBOY DESIGN         8
# 541902    581587     22629                  SPACEBOY LUNCH BOX         12
# 541903    581587     23256          CHILDRENS CUTLERY SPACEBOY          4
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 541889 2011-12-09 12:31:00       1.95     15804.0  United Kingdom
# 541890 2011-12-09 12:49:00       2.95     13113.0  United Kingdom
# 541891 2011-12-09 12:49:00       1.25     13113.0  United Kingdom
# 541892 2011-12-09 12:49:00       8.95     13113.0  United Kingdom
# 541893 2011-12-09 12:49:00       7.08     13113.0  United Kingdom
# 541894 2011-12-09 12:50:00       1.95     12680.0          France
# 541895 2011-12-09 12:50:00       1.65     12680.0          France
# 541896 2011-12-09 12:50:00       1.65     12680.0          France
# 541897 2011-12-09 12:50:00       3.75     12680.0          France
# 541898 2011-12-09 12:50:00       3.75     12680.0          France
# 541899 2011-12-09 12:50:00       3.75     12680.0          France
# 541900 2011-12-09 12:50:00       3.75     12680.0          France
# 541901 2011-12-09 12:50:00       1.95     12680.0          France
# 541902 2011-12-09 12:50:00       1.95     12680.0          France
# 541903 2011-12-09 12:50:00       4.15     12680.0          France
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France

# %%
# ordered ascending timestamp

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
print("Missing Number of CustomerID : ")
print( df["CustomerID"].isnull().sum())
print("Missing Number of Description : ")
print( df["Description"].isnull().sum())
# Out:
# Missing Number of CustomerID :
# 135080
# Missing Number of Description :
# 1454

# %%
# Percentage of missing valuse.

df.isnull().sum()/ df.shape[0]
# Out:
# InvoiceNo      0.000000
# StockCode      0.000000
# Description    0.002683
# Quantity       0.000000
# InvoiceDate    0.000000
# UnitPrice      0.000000
# CustomerID     0.249267
# Country        0.000000
# dtype: float64

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# ### i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.

# %% [markdown]
# We see that there are negative values in the Quantity and UnitPrice columns. These are possibly canceled and returned orders. Let's check it out.

# %%
df[['InvoiceNo', 'Quantity', 'UnitPrice']].head(5)
# Out:
#   InvoiceNo  Quantity  UnitPrice
# 0    536365         6       2.55
# 1    536365         6       3.39
# 2    536365         8       2.75
# 3    536365         6       3.39
# 4    536365         6       3.39

# %%
df[["InvoiceNo", "Quantity", "UnitPrice"]].describe().T.style.background_gradient(subset=['mean','std','50%','count'], cmap='RdPu')
# Out:
# <style type="text/css">
# #T_3fe1b_row0_col0, #T_3fe1b_row1_col0, #T_3fe1b_row1_col1, #T_3fe1b_row1_col2, #T_3fe1b_row1_col5 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_3fe1b_row0_col1, #T_3fe1b_row0_col2, #T_3fe1b_row0_col5 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3fe1b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3fe1b_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_3fe1b_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_3fe1b_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_3fe1b_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_3fe1b_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_3fe1b_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_3fe1b_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_3fe1b_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3fe1b_level0_row0" class="row_heading level0 row0" >Quantity</th>
#       <td id="T_3fe1b_row0_col0" class="data row0 col0" >401604.000000</td>
#       <td id="T_3fe1b_row0_col1" class="data row0 col1" >12.183273</td>
#       <td id="T_3fe1b_row0_col2" class="data row0 col2" >250.283037</td>
#       <td id="T_3fe1b_row0_col3" class="data row0 col3" >-80995.000000</td>
#       <td id="T_3fe1b_row0_col4" class="data row0 col4" >2.000000</td>
#       <td id="T_3fe1b_row0_col5" class="data row0 col5" >5.000000</td>
#       <td id="T_3fe1b_row0_col6" class="data row0 col6" >12.000000</td>
#       <td id="T_3fe1b_row0_col7" class="data row0 col7" >80995.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3fe1b_level0_row1" class="row_heading level0 row1" >UnitPrice</th>
#       <td id="T_3fe1b_row1_col0" class="data row1 col0" >401604.000000</td>
#       <td id="T_3fe1b_row1_col1" class="data row1 col1" >3.474064</td>
#       <td id="T_3fe1b_row1_col2" class="data row1 col2" >69.764035</td>
#       <td id="T_3fe1b_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_3fe1b_row1_col4" class="data row1 col4" >1.250000</td>
#       <td id="T_3fe1b_row1_col5" class="data row1 col5" >1.950000</td>
#       <td id="T_3fe1b_row1_col6" class="data row1 col6" >3.750000</td>
#       <td id="T_3fe1b_row1_col7" class="data row1 col7" >38970.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df[["InvoiceNo", "Quantity", "UnitPrice"]].describe(include=object).T
# Out:
#             count  unique     top  freq
# InvoiceNo  401604   22190  576339   542

# %%
# Filter rows where either Quantity or UnitPrice is negative
negative_values_df = df[(df['Quantity'] < 0) | (df['UnitPrice'] < 0)]

# Show the first few rows of the filtered DataFrame
negative_values_df.sample(20)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 29203    C538711     22460       EMBOSSED GLASS TEALIGHT HOLDER        -1
# 319912   C564940     23207            LUNCH BAG ALPHABET DESIGN      -250
# 333040   C566165     20914  SET/5 RED RETROSPOT LID GLASS BOWLS        -4
# 382801   C569955     23110              PARISIENNE KEY CABINET         -2
# 390002   C570487      CRUK                      CRUK Commission        -1
# 405023   C571707     23194           GYMKHANA TREASURE BOOK BOX        -4
# 24214    C538344     22867              HAND WARMER BIRD DESIGN       -12
# 214736   C555605     22971              QUEENS GUARD COFFEE MUG        -2
# 41619    C539947     21363              HOME SMALL WOOD LETTERS        -6
# 80220    C543026     22768           FAMILY PHOTO FRAME CORNICE        -2
# 443824   C574712     22393          PAPERWEIGHT VINTAGE COLLAGE        -1
# 51157    C540643     22423             REGENCY CAKESTAND 3 TIER        -2
# 492207   C578097     22112           CHOCOLATE HOT WATER BOTTLE       -48
# 374639   C569390         M                               Manual        -1
# 178015    552221     21043                                  NaN       -38
# 86862    C543606     22847          BREAD BIN DINER STYLE IVORY        -1
# 487973   C577786     22469                HEART OF WICKER SMALL       -40
# 355692   C567964     22307     GOLD MUG BONE CHINA TREE OF LIFE        -7
# 209732   C555268     23057     BEADED CHANDELIER T-LIGHT HOLDER        -1
# 19446    C537860     20676                   RED RETROSPOT BOWL        -8
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 29203  2010-12-14 10:50:00       1.25     15468.0  United Kingdom
# 319912 2011-08-31 13:10:00       1.45     12931.0  United Kingdom
# 333040 2011-09-09 11:57:00       2.95     14911.0            EIRE
# 382801 2011-10-06 18:35:00       5.75     17644.0  United Kingdom
# 390002 2011-10-10 17:12:00     411.92     14096.0  United Kingdom
# 405023 2011-10-18 15:33:00       2.25     14056.0  United Kingdom
# 24214  2010-12-10 14:32:00       2.10     13448.0  United Kingdom
# 214736 2011-06-06 11:38:00       2.55     15281.0  United Kingdom
# 41619  2010-12-23 11:47:00       4.95     13854.0  United Kingdom
# 80220  2011-02-02 14:44:00       9.95     16717.0  United Kingdom
# 443824 2011-11-06 14:25:00       2.55     14502.0  United Kingdom
# 51157  2011-01-10 14:08:00      10.95     12471.0         Germany
# 492207 2011-11-22 17:31:00       4.25         NaN  United Kingdom
# 374639 2011-10-03 16:53:00     120.00     15502.0  United Kingdom
# 178015 2011-05-06 15:20:00       0.00         NaN  United Kingdom
# 86862  2011-02-10 14:13:00      16.95     14665.0  United Kingdom
# 487973 2011-11-21 16:27:00       1.45     13246.0  United Kingdom
# 355692 2011-09-23 09:20:00       1.06     12995.0  United Kingdom
# 209732 2011-06-01 16:17:00       4.95     18257.0  United Kingdom
# 19446  2010-12-08 16:15:00       1.25     16252.0  United Kingdom

# %%
# not all of invoices with quantity < 0 are cancellations, some of them might be refunds

# %%
# Filter rows where UnitPrice is less than 0
invoices_with_negative_unit_price = df[df['UnitPrice'] < 0]

# Show the first few rows of the filtered DataFrame
invoices_with_negative_unit_price.head()
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
# there are only 2 with UnitPrice < 0, those have CustomerId = NaN
# Unit Price < 0 means bad debt

# %%
# Count the number of unique InvoiceNo that start with 'A' in the DataFrame with valid CustomerID
count_invoice_starts_with_A = df['InvoiceNo'].apply(lambda x: str(x).startswith('A'))

# Display the count
count_invoice_starts_with_A
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Name: InvoiceNo, Length: 541909, dtype: bool

# %%
# Filter rows where InvoiceNo starts with 'A' in the DataFrame with valid CustomerID
invoices_starts_with_A = df[df['InvoiceNo'].apply(lambda x: str(x).startswith('A'))]

# Show the filtered DataFrame
invoices_starts_with_A
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299982   11062.06         NaN  United Kingdom
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
# All invioces starting with A are "bad debt"

# %%
print("-------------------------")
print("Total number of customers: ")
print(df["CustomerID"].nunique())
print("-------------------------")
print("Total number of Missing Customers: ")
print(df["CustomerID"].isna().sum())
# Out:
# -------------------------
# Total number of customers:
# 4372
# -------------------------
# Total number of Missing Customers:
# 135080

# %%
# Drop rows where CustomerID is NaN (not a number)
df = df[df['CustomerID'].notna()]

# Show the first few rows of the DataFrame after dropping rows with NaN CustomerID
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (406829, 8)

# %%
# Filter rows where Quantity is less than 0 in the DataFrame with valid CustomerID
negative_quantity_with_valid_customerID = df[df['Quantity'] < 0]

# Count the number of such rows
count_negative_quantity = len(negative_quantity_with_valid_customerID)

# Display the count
count_negative_quantity
# Out:
# 8905

# %%
# Filter rows where UnitPrice is less than 0 in the DataFrame with valid CustomerID
negative_unit_price_with_valid_customerID = df[df['UnitPrice'] < 0]

# Count the number of such rows
count_negative_unit_price = len(negative_unit_price_with_valid_customerID)

# Display the count
count_negative_unit_price
# Out:
# 0

# %%
# no more rows with unit price < 0

# %% [markdown]
# ### ii. What does the letter "C" in the InvoiceNo column mean?

# %%
df['InvoiceNo'].nunique()
# Out:
# 22190

# %%
print("invoiceno Starts with C:")
df['InvoiceNo'].str.startswith('C').value_counts(dropna = False)
# Out:
# invoiceno Starts with C:
# NaN     397924
# True      8905
# Name: InvoiceNo, dtype: int64

# %%
# First, filter rows where 'Quantity' is less than 0
negative_quantity_df = df[df['Quantity'] < 0]

# Then, within those rows, filter out the ones where 'InvoiceNo' starts with 'C'
# Note that we're using 'loc' for row-based filtering here
negative_quantity_no_C = negative_quantity_df.loc[
    negative_quantity_df['InvoiceNo'].apply(lambda x: not str(x).startswith('C'))
]

# Show the first few rows of the filtered DataFrame
negative_quantity_no_C.value_counts()
# Out:
# Series([], dtype: int64)

# %%
# all rows with invoices starting with C have negative quantities.

# %% [markdown]
# hint: If the invoice number starts with the letter "C", it means the order was cancelled. Or those who abandon their order.

# %% [markdown]
# When we filter canceled orders by Quantity> 0 or filter non-canceled orders by Quantity <0 nothing returns, this confirms that negative values mean the order was canceled. So lets find out how many orders were cancelled?

# %%
# Count the number of unique InvoiceNo that start with 'C' in the DataFrame with valid CustomerID
count_invoice_starts_with_C = df['InvoiceNo'].apply(lambda x: str(x).startswith('C')).sum()

# Display the count
count_invoice_starts_with_C
# Out:
# 8905

# %%
df[df["InvoiceNo"].str.startswith('C').fillna(False)][["InvoiceNo", "Quantity", "UnitPrice"]]
# [["InvoiceNo", "Quantity", "UnitPrice"]]
# Out:
#        InvoiceNo  Quantity  UnitPrice
# 141      C536379        -1      27.50
# 154      C536383        -1       4.65
# 235      C536391       -12       1.65
# 236      C536391       -24       0.29
# 237      C536391       -24       0.29
# ...          ...       ...        ...
# 540449   C581490       -11       0.83
# 541541   C581499        -1     224.69
# 541715   C581568        -5      10.95
# 541716   C581569        -1       1.25
# 541717   C581569        -5       1.25
#
# [8905 rows x 3 columns]

# %%
quantity_values = (df['Quantity'] < 0).value_counts()
quantity_values = pd.DataFrame(quantity_values)
quantity_values.rename(index={False: 'Invoices Bigger Than 0', True: 'Invoices Smaller Than 0'}, inplace=True)
quantity_values
# Out:
#                          Quantity
# Invoices Bigger Than 0     392732
# Invoices Smaller Than 0      8872

# %%
cancelled_orders = (df['InvoiceNo'].str.startswith('C').value_counts())
cancelled_orders = pd.DataFrame(cancelled_orders)
cancelled_orders.rename(index={False: 'Non-Cancelled Orders', True: 'Cancelled Orders'}, inplace=True)
cancelled_orders
# Out:
#                   InvoiceNo
# Cancelled Orders       8872

# %%
# pip install plotly

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as pyo

# %%
pyo.init_notebook_mode()

# %%
# conda install "notebook>=5.3" "ipywidgets>=7.2"
# Out:
# zsh:1: 5.3 not found
#
# Note: you may need to restart the kernel to use updated packages.

# %%
fig = px.pie(quantity_values, 
             values = quantity_values['Quantity'], 
             names = quantity_values.index, 
             title = 'Quantity Smaller/Bigger')

fig.show()
# Out:
# <div>                            <div id="2ea7ac3d-1b20-4a4a-a83a-80d15f78cc66" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ea7ac3d-1b20-4a4a-a83a-80d15f78cc66")) {                    Plotly.newPlot(                        "2ea7ac3d-1b20-4a4a-a83a-80d15f78cc66",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}\u003cbr\u003eQuantity=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Invoices Bigger Than 0","Invoices Smaller Than 0"],"legendgroup":"","name":"","showlegend":true,"values":[392732,8872],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"mark ...
#
# var gd = document.getElementById('2ea7ac3d-1b20-4a

# %%
# Cancelled Orders Pie chart

fig = px.pie(cancelled_orders, 
             values = cancelled_orders['InvoiceNo'], 
             names = cancelled_orders.index, 
             title = 'The Proportion of Canceled Orders')

fig.show()
# Out:
# <div>                            <div id="5ea26bd9-b415-43ee-ac41-70948fdd6d27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ea26bd9-b415-43ee-ac41-70948fdd6d27")) {                    Plotly.newPlot(                        "5ea26bd9-b415-43ee-ac41-70948fdd6d27",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}\u003cbr\u003eInvoiceNo=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Cancelled Orders"],"legendgroup":"","name":"","showlegend":true,"values":[8872],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay"," ...
#
# var gd = document.getElementById('5ea26bd9-b415-43ee-ac41-70948fdd6d27');
# var x = n

# %%
# see above

# %%
# finding the original order of cancellation orders.

# %% [markdown]
# #### Looking deeper into why these orders were cancelled may prevent future cancellations. Now let's find out what a negative UnitPrice means.

# %%
# see above, bad debt, invoices starting with A, no more left after deleting all lines with customer = NaN

# %% [markdown]
# - 9288 or 1.7% (Original dataset) / 8872 or 2% (Tortured dataset) orders were cancelled.
# - 36% --> cancelled and at the same time ["customerid"].nunique() ratio.
# - Looking deeper into why these orders were cancelled may prevent future cancellations. Now let's find out what a negative UnitPrice means.

# %%
# for Robin

# %% [markdown]
# ### iii. Handling Missing Values

# %% [markdown]
# Since the customer ID's are missing, lets assume these orders were not made by the customers already in the data set because those customers already have ID's.
#
# We also don't want to assign these orders to those customers because this would alter the insights we draw from the data.

# %%
# I dropped them because I can't analyse customers I don't know and I assume that those orders did not come from my alreay existing customer base

# %% [markdown]
# ### iv. Clean the Data from the Noise and Missing Values

# %%
missing_values(df)

# %%
# Check for missing values in the original df DataFrame
missing_values_in_df = df.isnull().sum()

# %%
# Display the number of missing values for each column
missing_values_in_df
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
# check duplicates

# %%
# Count the number of duplicate rows based on all columns
duplicate_count = df.duplicated().sum()
duplicate_count
# Out:
# 5225

# %%
df.shape
# Out:
# (406829, 8)

# %%
# Remove duplicate rows based on all columns
df = df.drop_duplicates()
df.shape
# Out:
# (401604, 8)

# %% [markdown]
# ### v. Explore the Orders

# %% [markdown]
# 1. Find the unique number of InvoiceNo  per customer

# %%
# Convert 'CustomerID' to integer type
df['CustomerID'] = df['CustomerID'].astype(int)

# %%
# Find the unique number of InvoiceNo per customer (CustomerID)
unique_invoices_per_customer = df.groupby('CustomerID')['InvoiceNo'].nunique()

# Display the result
unique_invoices_per_customer
# Out:
# CustomerID
# 12346     2
# 12347     7
# 12348     4
# 12349     1
# 12350     1
#          ..
# 18280     1
# 18281     1
# 18282     3
# 18283    16
# 18287     3
# Name: InvoiceNo, Length: 4372, dtype: int64

# %% [markdown]
# 2. What's the average number of unqiue items per order or per customer?

# %%
# Calculate the average number of unique items per order
avg_unique_items_per_order = df.groupby('InvoiceNo')['StockCode'].nunique().mean()
avg_unique_items_per_order
# Out:
# 17.87656602073006

# %%
df['CustomerID'].nunique()
# Out:
# 4372

# %%
df["StockCode"].nunique()
# Out:
# 3684

# %%
df["Description"].nunique()
# Out:
# 3896

# %% [markdown]
# The number of "stockcode" & "description" should be the same; however, there is a difference.

# %% [markdown]
# 3. Let's see how this compares to the number of unique products per customer.

# %%
# Calculate the average number of unique items per customer
avg_unique_items_per_customer = df.groupby('CustomerID')['StockCode'].nunique().mean()
avg_unique_items_per_customer
# Out:
# 61.21111619396157

# %%
# the distribution of number of purchases unique per customer

# %% [markdown]
# ### vi. Explore Customers by Country

# %%
print(df["Country"].unique())
print("-------------------------")
print("Total number of country: ")
print(df["Country"].nunique())
# Out:
# ['United Kingdom' 'France' 'Australia' 'Netherlands' 'Germany' 'Norway'
#  'EIRE' 'Switzerland' 'Spain' 'Poland' 'Portugal' 'Italy' 'Belgium'
#  'Lithuania' 'Japan' 'Iceland' 'Channel Islands' 'Denmark' 'Cyprus'
#  'Sweden' 'Austria' 'Israel' 'Finland' 'Greece' 'Singapore' 'Lebanon'
#  'United Arab Emirates' 'Saudi Arabia' 'Czech Republic' 'Canada'
#  'Unspecified' 'Brazil' 'USA' 'European Community' 'Bahrain' 'Malta' 'RSA']
# -------------------------
# Total number of country:
# 37

# %% [markdown]
# 1. What's the total revenue per country?

# %%
# Calculate the total revenue for each row
df['TotalRevenue'] = df['Quantity'] * df['UnitPrice']

# Calculate the total revenue per country
total_revenue_per_country = df.groupby('Country')['TotalRevenue'].sum().sort_values(ascending=False)
total_revenue_per_country
# Out:
# Country
# United Kingdom          6747156.154
# Netherlands              284661.540
# EIRE                     250001.780
# Germany                  221509.470
# France                   196626.050
# Australia                137009.770
# Switzerland               55739.400
# Spain                     54756.030
# Belgium                   40910.960
# Sweden                    36585.410
# Japan                     35340.620
# Norway                    35163.460
# Portugal                  28995.760
# Finland                   22326.740
# Channel Islands           20076.390
# Denmark                   18768.140
# Italy                     16890.510
# Cyprus                    12858.760
# Austria                   10154.320
# Singapore                  9120.390
# Poland                     7213.140
# Israel                     6988.400
# Greece                     4710.520
# Iceland                    4310.000
# Canada                     3666.380
# Unspecified                2660.770
# Malta                      2505.470
# United Arab Emirates       1902.280
# USA                        1730.920
# Lebanon                    1693.880
# Lithuania                  1661.060
# European Community         1291.750
# Brazil                     1143.600
# RSA                        1002.310
# Czech Republic              707.720
# Bahrain                     548.400
# Saudi Arabia                131.170
# Name: TotalRevenue, dtype: float64

# %%
# Calculate the 'TotalRevenue' for each row
df['TotalRevenue'] = df['Quantity'] * df['UnitPrice']

# Calculate the total revenue across all countries
total_revenue = df['TotalRevenue'].sum()

# Calculate total revenue per country
total_revenue_per_country = df.groupby('Country')['TotalRevenue'].sum()

# Calculate the percentage of total revenue per country
percentage_revenue_per_country = (total_revenue_per_country / total_revenue) * 100

# Sort the values in descending order
percentage_revenue_per_country = percentage_revenue_per_country.sort_values(ascending=False)
percentage_revenue_per_country
# Out:
# Country
# United Kingdom          81.501967
# Netherlands              3.438556
# EIRE                     3.019885
# Germany                  2.675714
# France                   2.375135
# Australia                1.655003
# Switzerland              0.673302
# Spain                    0.661423
# Belgium                  0.494182
# Sweden                   0.441932
# Japan                    0.426895
# Norway                   0.424755
# Portugal                 0.350253
# Finland                  0.269695
# Channel Islands          0.242512
# Denmark                  0.226709
# Italy                    0.204028
# Cyprus                   0.155327
# Austria                  0.122659
# Singapore                0.110169
# Poland                   0.087131
# Israel                   0.084416
# Greece                   0.056901
# Iceland                  0.052062
# Canada                   0.044288
# Unspecified              0.032141
# Malta                    0.030265
# United Arab Emirates     0.022979
# USA                      0.020909
# Lebanon                  0.020461
# Lithuania                0.020065
# European Community       0.015604
# Brazil                   0.013814
# RSA                      0.012107
# Czech Republic           0.008549
# Bahrain                  0.006624
# Saudi Arabia             0.001584
# Name: TotalRevenue, dtype: float64

# %% [markdown]
# 2. Visualize number of customer per country

# %%
# for Nurgul

# %%
# Calculate the number of customers per country
num_customers_per_country = df.groupby('Country')['CustomerID'].nunique().sort_values(ascending=False)
num_customers_per_country
# Out:
# Country
# United Kingdom          3950
# Germany                   95
# France                    87
# Spain                     31
# Belgium                   25
# Switzerland               21
# Portugal                  19
# Italy                     15
# Finland                   12
# Austria                   11
# Norway                    10
# Netherlands                9
# Australia                  9
# Denmark                    9
# Channel Islands            9
# Cyprus                     8
# Sweden                     8
# Japan                      8
# Poland                     6
# USA                        4
# Canada                     4
# Unspecified                4
# Israel                     4
# Greece                     4
# EIRE                       3
# Malta                      2
# United Arab Emirates       2
# Bahrain                    2
# Czech Republic             1
# Lithuania                  1
# Lebanon                    1
# RSA                        1
# Saudi Arabia               1
# Singapore                  1
# Iceland                    1
# Brazil                     1
# European Community         1
# Name: CustomerID, dtype: int64

# %%
df['CustomerID'].nunique()
# Out:
# 4372

# %%
df.groupby('CustomerID')['Country'].nunique().value_counts()
# Out:
# 1    4364
# 2       8
# Name: Country, dtype: int64

# %% [markdown]
# We have 4364 unique "customerid". But while we are grouping them by using by "country" column; we notice that our unique number of customers is increasing.
# It means that a total of 8 customerids are included in multiple countries. For ex: '12431.0'

# %%
# Plotting the data
plt.figure(figsize=(15, 8))
sns.barplot(x=num_customers_per_country.values, y=num_customers_per_country.index, palette='viridis')
plt.title('Number of Customers per Country')
plt.xlabel('Number of Customers')
plt.ylabel('Country')
plt.show()

# %%
# Customers Without The UK

dfg1_w_oUK = df.groupby('Country')["CustomerID"].nunique().sort_values(ascending=False).iloc[1:]
fig = px.bar(x=dfg1_w_oUK.index, 
             y=dfg1_w_oUK, 
             title="Customers By Countries Without The UK", 
             labels=dict(x="Countries", y="Total Number of Customers Without The UK"))

# also works with graph_objects:
# fig = go.Figure(go.Bar(x=dfg.index, y=dfg))
fig.show()
# Out:
# <div>                            <div id="424ea0ee-ebc2-4048-a042-6e84f86c664d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("424ea0ee-ebc2-4048-a042-6e84f86c664d")) {                    Plotly.newPlot(                        "424ea0ee-ebc2-4048-a042-6e84f86c664d",                        [{"alignmentgroup":"True","hovertemplate":"Countries=%{x}\u003cbr\u003eTotal Number of Customers Without The UK=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Germany","France","Spain","Belgium","Switzerland","Portugal","Italy","Finland","Austria","Norway","Netherlands","Australia","Denmark","Channel Islands","Cyprus","Sweden","Japan","Poland","USA","Canada","Unspecified","Israel","Greece","EIRE","Malta","United Arab Emirates","Bahrain","Czech Republic","Lithuania","Lebanon","RSA","Saudi Arabia","Singapore","Iceland","Brazil","European Community"],"xaxis":"x","y":[95,87,31,25,21,19,15,12,11,10,9,9,9,9,8,8,8,6,4,4,4,4,4,3,2,2,2,1,1,1,1,1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"p ...

# %%
# may we can use wordcloud

fig = px.treemap(dfg1, path=[dfg1.index], values='CustomerID', width=950, height=600)
fig.update_layout(title_text='Customers By Countries',
                  title_x=0.5, title_font=dict(size=20)
                  )
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
fig.show()

# %%
# Importing necessary libraries for visualization (if not already imported)
import matplotlib.pyplot as plt

# Plotting the number of customers per country as a pie chart
plt.figure(figsize=(12, 12))
plt.pie(num_customers_per_country, labels=num_customers_per_country.index, autopct='%1.1f%%', startangle=90)
plt.title('Number of Customers per Country')
plt.show()

# %% [markdown]
# 3. Visualize total cost per country

# %%
# Plotting the total revenue per country as a bar chart with custom formatting for the x-axis labels
plt.figure(figsize=(15, 8))
sns.barplot(x=total_revenue_per_country.values, y=total_revenue_per_country.index, palette='mako')
plt.title('Total Revenue per Country')
plt.xlabel('Total Revenue')
plt.ylabel('Country')

# Customize x-axis labels to avoid scientific notation
plt.ticklabel_format(style='plain', axis='x')
plt.xticks(rotation=45)

plt.show()

# %%
# Customers Without The UK

dfg2_w_oUK = df.groupby('country')["customerid"].nunique().sort_values(ascending=False).iloc[1:]
fig = px.bar(x=dfg2_w_oUK.index, 
             y=dfg2_w_oUK, 
             title="Customers By Countries Without The UK", 
             labels=dict(x="Countries", y="Total Number of c"))

# also works with graph_objects:
# fig = go.Figure(go.Bar(x=dfg.index, y=dfg))
fig.show()

# %%
# Plotting the total revenue per country as a pie chart
plt.figure(figsize=(12, 12))
plt.pie(total_revenue_per_country, labels=total_revenue_per_country.index, autopct='%1.1f%%', startangle=90)
plt.title('Total Revenue per Country')
plt.show()

# %% [markdown]
# #### The UK not only has the most sales revenue, but also the most customers. Since the majority of this data set contains orders from the UK, we can explore the UK market further by finding out what products the customers buy together and any other buying behaviors to improve our sales and targeting strategy.

# %% [markdown]
# ### vii. Explore the UK Market

# %% [markdown]
# 1. Create df_uk DataFrame

# %%
# Create a DataFrame containing only the records from the United Kingdom
df_uk = df[df['Country'] == 'United Kingdom']

# %%
df_uk.shape
# Out:
# (356728, 9)

# %%
df_uk.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalRevenue
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom         15.30
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom         20.34
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom         22.00
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom         20.34
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom         20.34

# %% [markdown]
# 2. What are the most popular products that are bought in the UK?

# %%
# Calculate the most popular products in the UK based on the quantity sold
most_popular_products_uk = df_uk.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)

# Plotting the most popular products in the UK
plt.figure(figsize=(12, 8))
sns.barplot(x=most_popular_products_uk.values, y=most_popular_products_uk.index, palette='coolwarm')
plt.title('Most Popular Products in the UK')
plt.xlabel('Total Quantity Sold')
plt.ylabel('Description')
plt.show()

# %%
# Calculate the most popular products in the UK based on the quantity sold
most_popular_products_uk = df_uk.groupby('StockCode')['Quantity'].sum().sort_values(ascending=False).head(10)

# Plotting the most popular products in the UK
plt.figure(figsize=(12, 8))
sns.barplot(x=most_popular_products_uk.values, y=most_popular_products_uk.index, palette='coolwarm')
plt.title('Most Popular Products in the UK')
plt.xlabel('Total Quantity Sold')
plt.ylabel('Stock Code of Product')
plt.show()

# %%
# Calculate the total revenue for each product in the UK
df_uk['TotalRevenue'] = df_uk['Quantity'] * df_uk['UnitPrice']

# Identify the most popular products based on total revenue
most_popular_products_uk_revenue = df_uk.groupby('StockCode')['TotalRevenue'].sum().sort_values(ascending=False).head(10)

# Plotting the most popular products in the UK based on total revenue
plt.figure(figsize=(12, 8))
sns.barplot(x=most_popular_products_uk_revenue.values, y=most_popular_products_uk_revenue.index, palette='coolwarm')
plt.title('Most Popular Products in the UK Based on Turnover')
plt.xlabel('Total Revenue')
plt.ylabel('Stock Code of Product')
plt.show()
# Out:
# /var/folders/vn/78_516p12yj8_056vvsyj3v00000gn/T/ipykernel_29169/2386461175.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_uk[df_uk["StockCode"] == 23843]
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
# 540422   C581484     23843  PAPER CRAFT , LITTLE BIRDIE    -80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 540421 2011-12-09 09:15:00       2.08       16446  United Kingdom
# 540422 2011-12-09 09:27:00       2.08       16446  United Kingdom
#
#         TotalRevenue
# 540421      168469.6
# 540422     -168469.6

# %%
df_uk[df_uk["StockCode"] == 23166]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 61619     541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 61624    C541433     23166  MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 187196    552953     23166  MEDIUM CERAMIC TOP STORAGE JAR         4
# 187718    553005     23166  MEDIUM CERAMIC TOP STORAGE JAR         5
# 187868    553009     23166  MEDIUM CERAMIC TOP STORAGE JAR         3
# 188644    553052     23166  MEDIUM CERAMIC TOP STORAGE JAR        48
# 189398    553149     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 189452    553152     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 189591    553160     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 190854    553212     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 191128    553339     23166  MEDIUM CERAMIC TOP STORAGE JAR        48
# 191165    553341     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 191581    553377     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 194462    553607     23166  MEDIUM CERAMIC TOP STORAGE JAR       240
# 194887    553678     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 195725    553739     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 196707    553860     23166  MEDIUM CERAMIC TOP STORAGE JAR         2
# 198115    554013     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 198839    554070     23166  MEDIUM CERAMIC TOP STORAGE JAR         9
# 199427    554098     23166  MEDIUM CERAMIC TOP STORAGE JAR         6
# 201030    554261     23166  MEDIUM CERAMIC TOP STORAGE JAR         2
# 201099    554268     23166  MEDIUM CERAMIC TOP STORAGE JAR         1
# 201570    554307     23166  MEDIUM CERAMIC TOP STORAGE JAR        96
# 202855    554504     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 203625   C554527     23166  MEDIUM CERAMIC TOP STORAGE JAR        -9
# 203736    554547     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 203959    554603     23166  MEDIUM CERAMIC TOP STORAGE JAR         2
# 203982    554617     23166  MEDIUM CERAMIC TOP STORAGE JAR         2
# 205051    554704     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 206032    554860     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 206594    554946     23166  MEDIUM CERAMIC TOP STORAGE JAR        48
# 211575    555388     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 212465    555486     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 213127    555522     23166  MEDIUM CERAMIC TOP STORAGE JAR        24
# 213679    555552     23166  MEDIUM CERAMIC TOP STORAGE JAR         4
# 213842    555558     23166  MEDIUM CERAMIC TOP STORAGE JAR         6
# 214166    555567     23166  MEDIUM CERAMIC TOP STORAGE JAR         8
# 214879    555635     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 215726    555731     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 218883    556079     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 220234    556128     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 220265    556139     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 221843    556283     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 222894    556460     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 223342    556481     23166  MEDIUM CERAMIC TOP STORAGE JAR         3
# 223613    556484     23166  MEDIUM CERAMIC TOP STORAGE JAR         6
# 224910    556579     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 227680    556892     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 230159    557124     23166  MEDIUM CERAMIC TOP STORAGE JAR         3
# 230275    557129     23166  MEDIUM CERAMIC TOP STORAGE JAR         2
# 234364   C557508     23166  MEDIUM CERAMIC TOP STORAGE JAR      -240
# 236190    557744     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 236969    557793     23166  MEDIUM CERAMIC TOP STORAGE JAR         8
# 238058    557894     23166  MEDIUM CERAMIC TOP STORAGE JAR         6
# 240461    558102     23166  MEDIUM CERAMIC TOP STORAGE JAR         2
# 241536    558232     23166  MEDIUM CERAMIC TOP STORAGE JAR         4
# 245847    558635     23166  MEDIUM CERAMIC TOP STORAGE JAR         3
# 248998    558877     23166  MEDIUM CERAMIC TOP STORAGE JAR         3
# 249933    558964     23166  MEDIUM CERAMIC TOP STORAGE JAR        48
# 252878    559142     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 253004    559153     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 258465    559653     23166  MEDIUM CERAMIC TOP STORAGE JAR         2
# 260298    559807     23166  MEDIUM CERAMIC TOP STORAGE JAR         4
# 260463    559813     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 261481    559864     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 262228    559905     23166  MEDIUM CERAMIC TOP STORAGE JAR        48
# 276513    561051     23166  MEDIUM CERAMIC TOP STORAGE JAR       144
# 281378    561518     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 285883    561926     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 285893    561933     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 286489    562031     23166  MEDIUM CERAMIC TOP STORAGE JAR         3
# 286778    562042     23166  MEDIUM CERAMIC TOP STORAGE JAR        24
# 287218    562096     23166  MEDIUM CERAMIC TOP STORAGE JAR         1
# 287353    562101     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 287534    562106     23166  MEDIUM CERAMIC TOP STORAGE JAR         1
# 287537    562106     23166  MEDIUM CERAMIC TOP STORAGE JAR         3
# 288465    562161     23166  MEDIUM CERAMIC TOP STORAGE JAR         4
# 288512    562163     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 290275    562371     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 290490    562377     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 295174    562774     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 295666    562807     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 296596    562924     23166  MEDIUM CERAMIC TOP STORAGE JAR        14
# 297530   C562952     23166  MEDIUM CERAMIC TOP STORAGE JAR        -1
# 298576    563024     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 299633    563137     23166  MEDIUM CERAMIC TOP STORAGE JAR         4
# 301100    563239     23166  MEDIUM CERAMIC TOP STORAGE JAR         1
# 301673    563351     23166  MEDIUM CERAMIC TOP STORAGE JAR         8
# 306736    563840     23166  MEDIUM CERAMIC TOP STORAGE JAR        24
# 308502    564020     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 310621    564191     23166  MEDIUM CERAMIC TOP STORAGE JAR         1
# 310653    564192     23166  MEDIUM CERAMIC TOP STORAGE JAR        24
# 311560    564305     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 314294    564630     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 314860    564660     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 315661    564733     23166  MEDIUM CERAMIC TOP STORAGE JAR         3
# 316081    564745     23166  MEDIUM CERAMIC TOP STORAGE JAR         2
# 316269    564753     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 324666    565411     23166  MEDIUM CERAMIC TOP STORAGE JAR         6
# 326058    565471     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 326947    565614     23166  MEDIUM CERAMIC TOP STORAGE JAR         6
# 328436    565776     23166  MEDIUM CERAMIC TOP STORAGE JAR        48
# 333318    566193     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 336547    566364     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 343089    566932     23166  MEDIUM CERAMIC TOP STORAGE JAR         1
# 343837    566972     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 344838    567104     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 345386    567165     23166  MEDIUM CERAMIC TOP STORAGE JAR         2
# 346588    567190     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 347869    567341     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 349004    567475     23166  MEDIUM CERAMIC TOP STORAGE JAR         1
# 349009    567475     23166  MEDIUM CERAMIC TOP STORAGE JAR         2
# 349380    567504     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
# 349848   C567535     23166  MEDIUM CERAMIC TOP STORAGE JAR        -1
# 353727    567821     23166  MEDIUM CERAMIC TOP STORAGE JAR         4
# 353881    567851     23166  MEDIUM CERAMIC TOP STORAGE JAR        48
# 360123    568212     23166  MEDIUM CERAMIC TOP STORAGE JAR         1
# 360467    568228     23166  MEDIUM CERAMIC TOP STORAGE JAR        12
#
# 345386          2.50
# 346588         15.00
# 347869         15.00
# 349004          1.25
# 349009          2.50
# 349380         15.00
# 349848         -1.25
# 353727          5.00
# 353881         49.92
# 360123          1.25
# 360467         15.00
# 363239         15.00
# 364438         15.00
# 364894         30.00
# 364967          2.50
# 365009          3.75
# 365219         15.00
# 365650          2.50
# 373160         15.00
# 383123         30.00
# 383442          3.75
# 388996         15.00
# 393110         49.92
# 396785          7.50
# 401269         15.00
# 404840         15.00
# 405596          6.25
# 407122          2.50
# 409097          2.50
# 409914         15.00
# 410428         12.50
# 413724          1.25
# 413776         15.00
# 415553          7.50
# 417461          3.75
# 418208          3.75
# 421501         -1.25
# 426189          2.50
# 427159         10.00
# 427506         15.00
# 431594          5.00
# 432728          1.25
# 440702         30.00
# 444397          2.50
# 446167          5.00
# 448783          3.75
# 448806          5.00
# 460579         49.92
# 468894          1.25
# 472160         12.50
# 475790          7.50
# 479406         15.00
# 480352          2.50
# 485743         30.00
# 485775         99.84
# 486930         49.92
# 487560         49.92
# 487906         60.00
# 488385         60.00
# 488717         49.92
# 499158         49.92
# 500499          1.25
# 504011         10.00
# 505500         15.00
# 507119          2.50
# 512817         12.50
# 513276         10.00
# 513981          6.25
# 516656         15.00
# 518967         15.00
# 524254         15.00
# 526381         99.84
# 531499          1.25
# 532826          5.00
# 533742          2.50

# %%
# Wolf will do it again.

# %%
cprint("The Number of Observations in the 'unitprice' Column Which Equal to 0",'blue')
df[df['UnitPrice']==0][['InvoiceNo', 'StockCode', 'Description', 'quantity', 'invoicedate', 'unitprice', 'customerid', 'country']].head()

# %%
cprint("Customer Status According to the Spendings (Top 5)",'blue')
df.groupby(['CustomerID', 'Country'])['TotalRevenue'].sum().sort_values(ascending=False).head()

# %%
cprint("Customer Status According to the Spendings (Bottom 5)",'blue')
df.groupby(['CustomerID', 'Country'])['TotalRevenue'].sum().sort_values().head()

# %%
# Customers per country

fig = px.histogram(df, x = df.groupby('Country')['CustomerID'].nunique().index, 
                   y = df.groupby('Country')['CustomerID'].nunique().values, 
                   title = 'The Number of Customers By Country',
                   labels = dict(x = "Countries", y ="Customer")).update_xaxes(categoryorder="total descending")
fig.show()

# %%
# International Customer

df_wo_UK = df.groupby('Country')["CustomerID"].nunique().sort_values(ascending=False).iloc[1:]

fig = px.histogram(df, x = df_wo_UK.index, 
                   y = df_wo_UK.values, 
                   title = 'The Number of Customers By Country Without UK',
                   labels = dict(x = "Countries", y ="Customer")).update_xaxes(categoryorder="total descending")
fig.show()

# %% [markdown]
# ## Invoice Date

# %%
df.InvoiceDate.max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
df.InvoiceDate.min()
# Out:
# Timestamp('2010-12-01 08:26:00')

# %%
# df["invoicedate"] = pd.to_datetime(df["invoicedate"])
# df.groupby('customerid')['invoicedate'].max()

# %% [markdown]
# ### We will continue analyzing the UK transactions with customer segmentation.

# %% [markdown]
# # 2. RFM Analysis

# %% [markdown]
# In the age of the internet and e-commerce, companies that do not expand their businesses online or utilize digital tools to reach their customers will run into issues like scalability and a lack of digital precsence. An important marketing strategy e-commerce businesses use for analyzing and predicting customer value is customer segmentation. Customer data is used to sort customers into group based on their behaviors and preferences.
#
# **[RFM](https://www.putler.com/rfm-analysis/) (Recency, Frequency, Monetary) Analysis** is a customer segmentation technique for analyzing customer value based on past buying behavior. RFM analysis was first used by the direct mail industry more than four decades ago, yet it is still an effective way to optimize your marketing.
# <br>
# <br>
# Our goal in this Notebook is to cluster the customers in our data set to:
#  - Recognize who are our most valuable customers
#  - Increase revenue
#  - Increase customer retention
#  - Learn more about the trends and behaviors of our customers
#  - Define customers that are at risk
#
# We will start with **RFM Analysis** and then compliment our findings with predictive analysis using **K-Means Clustering Algorithms.**
#
# - RECENCY (R): Time since last purchase
# - FREQUENCY (F): Total number of purchases
# - MONETARY VALUE (M): Total monetary value
#
#
#
#
# Benefits of RFM Analysis
#
# - Increased customer retention
# - Increased response rate
# - Increased conversion rate
# - Increased revenue
#
# RFM Analysis answers the following questions:
#  - Who are our best customers?
#  - Who has the potential to be converted into more profitable customers?
#  - Which customers do we need to retain?
#  - Which group of customers is most likely to respond to our marketing campaign?

# %% [markdown]
# ### i. Import Libraries

# %%
import datetime as dt
from datetime import datetime
from datetime import timedelta

# %% [markdown]
# ### ii. Review df_uk DataFrame

# %%
df_uk.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalRevenue
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom         15.30
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom         20.34
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom         22.00
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom         20.34
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom         20.34

# %% [markdown]
# ### iii. Recency: Days since last purchase
# To calculate the recency values, follow these steps in order:
#
# 1. To calculate recency, we need to choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.
# 2. Create a new column called Date which contains the invoice date without the timestamp
# 3. Group by CustomerID and check the last date of purchase
# 4. Calculate the days since last purchase
# 5. Drop Last_Purchase_Date since we don't need it anymore
# 6. Plot RFM distributions

# %% [markdown]
# 1. Choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.

# %%
# Find the last transaction date
last_transaction_date = df_uk['InvoiceDate'].max()
print(f"The last transaction date is {last_transaction_date}")
# Out:
# The last transaction date is 2011-12-09 12:49:00

# %%
# Set the reference date as one day after the last transaction date
reference_date = last_transaction_date + pd.Timedelta(days=1)
print(f"The reference date is {reference_date}")
# Out:
# The reference date is 2011-12-10 12:49:00

# %% [markdown]
# 2. Create a new column called Date which contains the invoice date without the timestamp

# %%
# Convert 'InvoiceDate' to datetime format if it's not already
df_uk['InvoiceDate'] = pd.to_datetime(df_uk['InvoiceDate'])

# Create a new column 'Date' containing only the date part of 'InvoiceDate'
df_uk['Date'] = df_uk['InvoiceDate'].dt.date
df_uk['Date']
# Out:
# /var/folders/vn/78_516p12yj8_056vvsyj3v00000gn/T/ipykernel_29169/717953213.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vn/78_516p12yj8_056vvsyj3v00000gn/T/ipykernel_29169/717953213.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0         2010-12-01
# 1         2010-12-01
# 2         2010-12-01
# 3         2010-12-01
# 4         2010-12-01
#              ...
# 541889    2011-12-09
# 541890    2011-12-09
# 541891    2011-12-09
# 541892    2011-12-09
# 541893    2011-12-09
# Name: Date, Length: 356728, dtype: object

# %%
df_uk['InvoiceDate']
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541889   2011-12-09 12:31:00
# 541890   2011-12-09 12:49:00
# 541891   2011-12-09 12:49:00
# 541892   2011-12-09 12:49:00
# 541893   2011-12-09 12:49:00
# Name: InvoiceDate, Length: 356728, dtype: datetime64[ns]

# %% [markdown]
# 3. Group by CustomerID and check the last date of purchase

# %%
# add last purchase date to df_uk

# %%
# Group by 'CustomerID' and find the last date of purchase for each customer
last_purchase_date_per_customer = df_uk.groupby('CustomerID')['Date'].max().reset_index()
last_purchase_date_per_customer
# Out:
#       CustomerID       Date
# 0          12346 2011-01-18
# 1          12747 2011-12-07
# 2          12748 2011-12-09
# 3          12749 2011-12-06
# 4          12820 2011-12-06
# ...          ...        ...
# 3945       18280 2011-03-07
# 3946       18281 2011-06-12
# 3947       18282 2011-12-02
# 3948       18283 2011-12-06
# 3949       18287 2011-10-28
#
# [3950 rows x 2 columns]

# %% [markdown]
# 4. Calculate the days since last purchase

# %%
# Convert 'Date' columns to datetime format
df_uk['Date'] = pd.to_datetime(df_uk['Date'])
last_purchase_date_per_customer['Date'] = pd.to_datetime(last_purchase_date_per_customer['Date'])

# Find the last transaction date in the dataset to use as a reference date
reference_date = df_uk['Date'].max() + pd.Timedelta(days=1)

# Calculate the number of days since the last purchase for each customer
last_purchase_date_per_customer['DaysSinceLastPurchase'] = (reference_date - last_purchase_date_per_customer['Date']).dt.days
# Out:
# /var/folders/vn/78_516p12yj8_056vvsyj3v00000gn/T/ipykernel_29169/3852745884.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_uk.sample(10)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 140810    548468     22776          SWEETHEART CAKESTAND 3 TIER         1
# 103013    545048     21080  SET/20 RED RETROSPOT PAPER NAPKINS          4
# 143244    548670     21054                 NURSE'S BAG SOFT TOY         1
# 117060    546330     22723        SET OF 6 HERB TINS SKETCHBOOK         4
# 152289    549584     21929       JUMBO BAG PINK VINTAGE PAISLEY        10
# 296328   C562884     22900      SET 2 TEA TOWELS I LOVE LONDON         -3
# 331522    566018     23281       FOLDING BUTTERFLY MIRROR RED           2
# 237151    557802     22176                    BLUE OWL SOFT TOY         6
# 478457    577082     22571         ROCKING HORSE RED CHRISTMAS         12
# 429553    573572     22114    HOT WATER BOTTLE TEA AND SYMPATHY         2
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 140810 2011-03-31 12:28:00       9.95       14818  United Kingdom
# 103013 2011-02-27 11:48:00       0.85       14810  United Kingdom
# 143244 2011-04-01 15:37:00       8.95       15356  United Kingdom
# 117060 2011-03-11 10:30:00       3.95       16817  United Kingdom
# 152289 2011-04-11 09:47:00       2.08       17574  United Kingdom
# 296328 2011-08-10 11:25:00       3.25       14056  United Kingdom
# 331522 2011-09-08 12:42:00       0.83       13137  United Kingdom
# 237151 2011-06-23 10:15:00       2.95       15130  United Kingdom
# 478457 2011-11-17 15:31:00       0.85       15811  United Kingdom
# 429553 2011-10-31 14:03:00       4.25       14527  United Kingdom
#
#         TotalRevenue       Date
# 140810          9.95 2011-03-31
# 103013          3.40 2011-02-27
# 143244          8.95 2011-04-01
# 117060         15.80 2011-03-11
# 152289         20.80 2011-04-11
# 296328         -9.75 2011-08-10
# 331522          1.66 2011-09-08
# 237151         17.70 2011-06-23
# 478457         10.20 2011-11-17
# 429553          8.50 2011-10-31

# %% [markdown]
# 5. Drop Last_Purchase_Date since we don't need it anymore

# %%
# Drop the 'Last_Purchase_Date' column if it exists
if 'Last_Purchase_Date' in last_purchase_date_per_customer.columns:
    last_purchase_date_per_customer.drop('Last_Purchase_Date', axis=1, inplace=True)

# %% [markdown]
# 6. Plot RFM distributions

# %%
# Calculate the total revenue for each row
df['TotalRevenue'] = df['Quantity'] * df['UnitPrice']

# %%
# Calculate Recency for each customer
recency_df = df.groupby('CustomerID').agg({
    'Date': lambda x: (reference_date - pd.to_datetime(x.max()).date()).days
}).reset_index()

# Rename the columns
recency_df.rename(columns = {'Date': 'Recency'}, inplace=True)

# Plotting the distribution for Recency
plt.figure(figsize=(12, 6))
sns.histplot(recency_df['Recency'], bins=50, color='skyblue')
plt.title('Recency Distribution')
plt.xlabel('Recency')
plt.ylabel('Frequency')
plt.show()

# %%
df.columns= df.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')

# %% [markdown]
# ### iv. Frequency: Number of purchases
#
# To calculate how many times a customer purchased something, we need to count how many invoices each customer has. To calculate the frequency values, follow these steps in order:

# %% [markdown]
# 1. Make a copy of df_uk and drop duplicates

# %% [markdown]
# 2. Calculate the frequency of purchases

# %% [markdown]
# 3. Plot RFM distributions

# %% [markdown]
# ### v. Monetary: Total amount of money spent
#
# The monetary value is calculated by adding together the cost of the customers' purchases.

# %% [markdown]
# 1. Calculate sum total cost by customers and named "Monetary"

# %% [markdown]
# 2. Plot RFM distributions

# %% [markdown]
# ### vi. Create RFM Table
# Merge the recency, frequency and motetary dataframes

# %%
# a DF with customer, last purchasing date, frequency and total sum of purchases

# %% [markdown]
# # 3. Customer Segmentation with RFM Scores

# %% [markdown]
# Businesses have this ever-lasting urge to understand their customers. The better you understand the customer, the better you serve them, and the higher the financial gain you receive from that customer. Since the dawn of trade, this process of understanding customers for a strategic gain has been there practiced and this task is known majorly as [Customer Segmentation](https://clevertap.com/blog/rfm-analysis/).
# Well as the name suggests, Customer Segmentation could segment customers according to their precise needs. Some of the common ways of segmenting customers are based on their Recency-Frequency-Monatory values, their demographics like gender, region, country, etc, and some of their business-crafted scores. You will use Recency-Frequency-Monatory values for this case.
#
# In this section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".

# %% [markdown]
# ## Calculate RFM Scoring
#
# The simplest way to create customer segments from an RFM model is by using **Quartiles**. We will assign a score from 1 to 4 to each category (Recency, Frequency, and Monetary) with 4 being the highest/best value. The final RFM score is calculated by combining all RFM values. For Customer Segmentation, you will use the df_rfm data set resulting from the RFM analysis.
# <br>
# <br>
# **Note**: Data can be assigned into more groups for better granularity, but we will use 4 in this case.

# %% [markdown]
# 1. Divide the df_rfm into quarters

# %% [markdown]
# ### i. Creating the RFM Segmentation Table

# %% [markdown]
# 1. Create two functions, one for Recency and one for Frequency and Monetary. For Recency, customers in the first quarter should be scored as 4, this represents the highest Recency value. Conversely, for Frequency and Monetary, customers in the last quarter should be scored as 4, representing the highest Frequency and Monetary values.

# %% [markdown]
# 2. Score customers from 1 to 4 by applying the functions you have created. Also create separate score column for each value.

# %% [markdown]
# 3. Now that scored each customer, you'll combine the scores for segmentation.

# %% [markdown]
# 4. Define rfm_level function that tags customers by using RFM_Scrores and Create a new variable RFM_Level

# %% [markdown]
# 5. Calculate average values for each RFM_Level, and return a size of each segment

# %% [markdown]
# ## Plot RFM Segments

# %% [markdown]
# 1. Create your plot and resize it.

# %% [markdown]
# Using customer segmentation categories found [here](http://www.blastam.com/blog/rfm-analysis-boosts-sales). We can formulate different marketing strategies and approaches for customer engagement for each type of customer.
#
# Note: The author in the article scores 1 as the highest and 4 as the lowest

# %% [markdown]
# 2. How many customers do we have in each segment?

# %% [markdown]
# # 3. Applying K-Means Clustering

# %% [markdown]
# Now that we have our customers segmented into different categories, we can gain further insight into customer behavior by using predictive models in conjuction with out RFM model.
# Possible algorithms include **Logistic Regression**, **K-means Clustering**, and **K-nearest Neighbor**. We will go with [K-Means](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1) since we already have our distinct groups determined. K-means has also been widely used for market segmentation and has the advantage of being simple to implement.

# %% [markdown]
# ## Data Pre-Processing and Exploring

# %% [markdown]
# ### i. Define and Plot Feature Correlations

# %% [markdown]
# Create Heatmap and evaluate the results

# %% [markdown]
# ### ii. Visualize Feature Distributions
#
# To get a better understanding of the dataset, you can costruct a scatter matrix of each of the three features in the RFM data.

# %% [markdown]
# ### iii. Data Normalization

# %% [markdown]
# 1. Logarithmic Tranformation can be used to normalize the values in a column.
# 2. Plot normalized data with scatter matrix or pairplot. Also evaluate results.

# %% [markdown]
# ## K-Means Implementation
#
# For k-means, you have to set k to the number of clusters you want, but figuring out how many clusters is not obvious from the beginning. We will try different cluster numbers and check their [silhouette coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html). The silhouette coefficient for a data point measures how similar it is to its assigned cluster from -1 (dissimilar) to 1 (similar).
# <br>
# <br>
# **Note**: K-means is sensitive to initializations because they are critical to qualifty of optima found. Thus, we will use smart initialization called "Elbow Method".

# %% [markdown]
# ### i. Define the Optimal Number of Clusters

# %% [markdown]
# [The Elbow Method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)

# %% [markdown]
# [Silhouette Coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html)

# %% [markdown]
# ### ii. Model Fitting

# %% [markdown]
# Fit the K-Means Algorithm with the optimal number of clusters you decided and save the model to disk.

# %% [markdown]
# ### iii. Visualize the Clusters

# %% [markdown]
# 1. Create a scatter plot and select cluster centers

# %% [markdown]
# 2. Visualize Cluster Id vs Recency, Cluster Id vs Frequency and Cluster Id vs Monetary using Box plot. Also evaluate the results.

# %% [markdown]
# ### iv. Assign the Label

# %% [markdown]
# ### v. Conclusion
#
# Discuss your final results. Compare your own labels from the RFM Customer Segmentation with the labels found by K-Means.

# %% [markdown]
# How we want to continue this analysis depends on how the business plans to use the results and the level of granularity the business stakeholders want to see in the clusters. We can also ask what range of customer behavior from high to low value customers are the stakeholders interested in exploring. From those answers, various methods of clustering can be used and applied on RFM variable or directly on the transaction data set.

# %% [markdown]
# **Annotation:**
#
# Limitations of K-means clustering:
#
# 1. There is no assurance that it will lead to the global best solution.
# 2. Can't deal with different shapes(not circular) and consider one point's probability of belonging to more than one cluster.
#
# These disadvantages of K-means show that for many datasets (especially low-dimensional datasets), it may not perform as well as you might hope.

# %% [markdown]
# **Conclusion**
#
# * Write down your conclusions about clustering

# %% [markdown]
# # 5. Create Cohort & Conduct Cohort Analysis
# [Cohort Analysis](https://medium.com/swlh/cohort-analysis-using-python-and-pandas-d2a60f4d0a4d) is specifically useful in analyzing user growth patterns for products. In terms of a product, a cohort can be a group of people with the same sign-up date, the same usage starts month/date, or the same traffic source.
# Cohort analysis is an analytics method by which these groups can be tracked over time for finding key insights. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.
#
# For e-commerce organizations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get the following answers to the following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employ to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasonality pattern in Customer behavior?
# - Along with various performance measures/metrics for your organization.

# %% [markdown]
# Since we will be performing Cohort Analysis based on transaction records of customers, the columns we will be dealing with mainly:
# - Invoice Data
# - CustomerID
# - Price
# - Quantity
#
# The following steps will performed to generate the Cohort Chart of Retention Rate:
# - Month Extraction from InvioceDate column
# - Assigning Cohort to Each Transaction
# - Assigning Cohort Index to each transaction
# - Calculating number of unique customers in each Group of (ChortDate,Index)
# - Creating Cohort Table for Retention Rate
# - Creating the Cohort Chart using the Cohort Table
#
# The Detailed information about each step is given below:

# %% [markdown]
# ## Future Engineering

# %% [markdown]
# ### i. Extract the Month of the Purchase
# First we will create a function, which takes any date and returns the formatted date with day value as 1st of the same month and Year.

# %% [markdown]
# Now we will use the function created above to convert all the invoice dates into respective month date format.

# %% [markdown]
# ### ii. Calculating time offset in Months i.e. Cohort Index:
# Calculating time offset for each transaction will allows us to report the metrics for each cohort in a comparable fashion.
# First, you will create 4 variables that capture the integer value of years, months for Invoice and Cohort Date using the get_date_int() function which you'll create it below.

# %% [markdown]
# You will use this function to extract the integer values for Invoice as well as Cohort Date in 3 separate series for each of the two columns

# %% [markdown]
# Use the variables created above to calcualte the difference in days and store them in cohort Index column.

# %% [markdown]
# ## Create 1st Cohort: User number & Retention Rate

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %% [markdown]
# ### ii. Visualize analysis of cohort 1 using seaborn and matplotlib modules

# %% [markdown]
# ## Create the 2nd Cohort: Average Quantity Sold

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %% [markdown]
# ### ii. Visualize analysis of cohort 2 using seaborn and matplotlib modules

# %% [markdown]
# ## Create the 3rd Cohort: Average Sales

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %% [markdown]
# ### ii. Visualize analysis of cohort 3 using seaborn and matplotlib modules

# %% [markdown]
# For e-commerce organisations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get answers to following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employed to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasoanlity pattern in Customer behahiour?

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
